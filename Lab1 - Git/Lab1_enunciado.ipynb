# %% [markdown]
# <h1><center>Laboratorio 1: Git 👾</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Primavera 2024</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesores: Ignacio Meza, Sebastián Tinoco
# - Auxiliar: Eduardo Moya
# - Ayudantes: Nicolás Ojeda, Melanie Peña, Valentina Rojas

# %% [markdown]
# ### Equipo: **SUPER IMPORTANTE - notebooks sin nombre no serán revisados**
#
# - Nombre de alumno 1: Francisca Ruiz
# - Nombre de alumno 2: Valentina Zúñiga

# %% [markdown]
# ### **Link de repositorio de GitHub:** [Lab1](https://github.com/vazuniga1/Laboratorios/tree/main/Lab1%20-%20Git)

# %% [markdown]
# ## Reglas:
#
# - **Grupos de 2 personas**
# - Fecha de entrega: 6 días de plazo con descuento de 1 punto por día. Entregas Jueves a las 23:59.
# - Instrucciones del lab el viernes a las 16:15 en formato online. Asistencia no es obligatoria.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Tienen que subir el laboratorio a u-cursos y a su repositorio de github. Labs que no estén en u-cursos no serán revisados. Recuerden que el repositorio también tiene nota.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Pueden usar cualquier material del curso que estimen conveniente.

# %% [markdown]
# ## Objetivos del lab:
#
#
# - Conocer los elementos básicos que conformar `Git`
# - Clonar repositorios
# - Identificar ramas de un repositorio
# - Reconocer y solucionar problemas entre ramas
# - Subir cambios a un repositorio

# %% [markdown]
# ## Parte 1: Conocimiento Teórico (2.5 pts)
#
# <p align="center">
#   <img src="https://cdn.thedesigninspiration.com/wp-content/uploads/sites/3/2019/04/macintosh-hdusersbrittanyloefflerdownloadsanig-1.gif" width="350">
# </p>

# %% [markdown]
# Responda las siguientes preguntas (0.2 pts c/u):
#
# 1. ¿Qué es `Git` y cómo se relaciona con el control de versiones?
#
# 2. Nombre y explique 3 diferencias entre `Git` y `Github`.
#
# 3. ¿Qué es un `hash` y cómo se representa en un `commit`? De un ejemplo.
#
# 4. ¿Que elementos componen a la estructura de datos de `Git`?
#
# 5. ¿Que comandos de `Git` sirven para crear un repositorio y hacer seguimiento a cambios en los archivos?

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
# 1. Git corresponde a un Sistema de Control de Versiones Distribuido (DVCS), donde se registran instancias donde un archivo o un conjunto de archivos fueron modificados, de esta manera permite que un grupo pueda trabajar de forma colaborativa.
#
# 2. - Git es un software de VCS local que permite a los desarrolladores guardar instaneas de sus proyectos a lo largo del tiempo, mientras que GitHub es una plataforma basada en la web que incorpora las características de control de versiones de git para que puedan ser utilizadas de forma colaborativa.
#
# - Los repositorios Git se almacenan localmente en el sistema de archivos del desarrollador, mientras que GitHub almacena los repositorios en la nube.
#
# - La visibilidad de los repositorios y el acceso de Git dependen de la configuración local del proyecto, mientras que GitHub tiene opciones para hacer los repositorios sean públicos o privados, lo que controla quién puede ver y contribuir en ellos.
#
# 3.  Un ‘hash’ consiste en un identificador único que se genera para identificar un ‘commit’ dentro de un repositorio. Es decir, cuando se realiza un ‘commit’ se le asigna un ‘hash’. Un ejemplo de esto es que si se realiza un commit para modificar un archivo ‘x.py’, a este se le asigna el hash ‘Y’, en caso de que se realice otro commit para modificar el mismo archivo, entonces el hash es distinto, por ejemplo ‘Z’, por lo que cada ‘commit’ aunque sea sobre un mismo archivo, recibe un hash único.
#
# 4. Los elementos que componen la estructura de datos de ‘Git’ son:
#     - Blobs (Binary Large Objects): Representa el contenido de un archivo.
#     - Trees (Árboles): Representa la jerarquía de directorios y archivos en un commit.
#     - Commits: Representa un estado completo del proyecto en un momento específico.
#
# 5. Para crear un nuevo repositorio se puede utilizar el comando git init, el cual es un comando que se utiliza una sola vez durante la configuración inicial de un repositorio nuevo. Al ejecutar este comando, se creará un nuevo subdirectorio .git en el directorio de trabajo actual. En el caso de querer clonar un repositorio existente, se puede utilizar el comando git clone el cual se usa para crear una copia o clonar un repositorio remoto.
#
# Para hacer seguimiento a los cambios en los archivos podemos utilizar los siguientes comandos:
#     - git status: Este comando muestra los diferentes estados de los archivos en el directorio de trabajo y área de ensayo; es decir, que archivos están modificados y sin seguimiento y cuáles con seguimiento pero no confirmados aún.
#     - git add: Este comando añade contenido del directorio de trabajo al área de ensayo para la próxima confirmación.
#     - git diff: Este comando se utiliza cuando se desea ver las diferencias entre dos árboles.
#     - git log: Este comando muestra el historial de confirmaciones del repositorio, se puede ver quién hizo cada cambio, cuando se realizó y qué mensaje de commit se incluyó.

# %% [markdown]
# Responda si las siguientes afirmaciones son Verdaderas (V) o Falsas (F). Justifique en **cualquiera** de los casos (0.2 pts c/u):
#
#
# 6. `Git` siempre resuelve automáticamente los problemas de lineas al hacer merge entre diferentes ramas.
# 7. Ejecutar `git pull` sobre un repositorio es equivalente a ejecutar `git clone`.
# 8. `git status` genera los mismos resultados que `git log`.
# 9. En `Git` es posible deshacer cambios y volver a versiones anteriores del código.
# 10. El comando `git commit` se utiliza para enviar cambios al repositorio remoto.

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>

# %% [markdown]
# 6. F. Cuando existen problemas entre ramas que impiden realizar el merge, entonces el proceso se detiene y le indica al usuario que
# hay conflictos que se deben resolver manualmente, indicando cuales son.
#
# 7. F. 'git clone' se utiliza para realizar una copia de un repositorio remoto y crear un nuevo repositorio local, mientras que 'git pull' se
# encarga de actualizar un repositorio local que ya existe con los cambios más recientes del repositorio.
#
# 8. F. 'git log' arroja el historial de 'commit' realizados en el repositorio, por otro lado, 'git status' muestra el estado del repositorio,
# es decir, cambios que se han hecho dentro del repositorio, incluyendo si hay archivos nuevos, cambios no confirmados y cambios preparados.
#
# 9. V. Si se quiere regresar a un commit anterior se puede utilizar el comando git reset, el cual tiene tres formas: -hard, -mixed, y -soft.
# También se puede utilizar el comando git reflog el cual permite recuperar commits eliminados, es como un historial de cambios detallados.
#
# 10. F. El comando que se utiliza para enviar cambios a un repositorio remoto es git push. El comando git commit se utiliza para crear una nueva
# confirmación local con los cambios que están en el área de preparación.

# %% [markdown]
# Por último, investigue y comente con sus palabras para qué sirven los siguientes comandos:
#
# 11. `git stash` (0.25 puntos)
# 12. `git reset`. ¿Cuál es la diferencia de este comando con `git revert`?. (0.25 puntos)

# %% [markdown]
# 11. El comando git stash se utiliza para almacenar todos los cambios actuales que no están confirmados para poder utilizarlos en un momento
# posterior. Es un comando que resulta útil cuando se han realizado cambios en una rama que no está lista para realizarle commit, pero se necesita
# cambiar a otra rama.
#
# 12. Ambos comandos sirven para deshacer cambios en el código y el historial de un proyecto, pero lo hacen de maneras distintas. El comando git
# reset se usa para deshacer cambios en el directorio de trabajo y volver a un commit específico, eliminando todos los commits posteriores a ese
# punto. Por otro lado, el comando git revert no elimina commits, sino que crea un nuevo commit que revierte los cambios realizados por un commit
# anterior, generando un contenido opuesto al original.

# %% [markdown]
# ## Parte 2: Creando una presentación personal (1.5 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/arqlNu8gyJYAAAAC/cat-cat-jumping.gif" width="150">
# </p>

# %% [markdown]
# Para empezar a "*soltar las manos*" con `Git`, se les encomienda crear un repositorio con una presentación personal. El repositorio debe contener un breve resumen de quienes son ustedes, sus gustos, experiencias, y cualquier otro detalle interesante que ustedes consideren relevante.
#
# Para realizar esto, deben seguir los siguientes pasos:
#
# 1. Contar con una cuenta de github (1 por persona)
# 2. Crear un repositorio con su nombre de usuario
# 3. Vincular el repositorio a su ambiente local ¿Qué comando(s) me permiten hacer esto?
# 4. Crear un archivo `readme.md` con la información que ustedes deseen compartir.
# 5. Realizar `push` con los cambios generados
#
# A modo de ejemplo, pueden guiarse por esta *suculenta* [presentación](https://github.com/Mezosky)
#
# **Nota: Deben trabajar todos estos puntos desde su ambiente local**
#
# *Hint: Una buena opción es usar templates de presentación personal que encuentren en Google, como los que ofrece este [sitio](https://durgeshsamariya.github.io/awesome-github-profile-readme-templates/#/)*.
#
# **Entregable:**
#
# Enlace al repositorio con la presentación personal.
#
# IMPORTANTE: DEBEN ADJUNTAR UN ENLACE POR PERSONA

# %% [markdown]
# <code>Link Presentacion 1:</code> https://github.com/franciscaruiz16
#
# <code>Link Presentacion 2:</code> https://github.com/vazuniga1

# %% [markdown]
# ## Parte 3: Trabajando sobre un repositorio externo (2 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/YXL-0SK15j4AAAAC/dance-animals.gif" width="300">
# </p>
#
# Tras muchos dolores de cabeza, un grupo de entusiastas académicos decidieron aprender sobre `Git` y así trabajar colaborativamente de forma más ordenada y eficiente. Después de una infinidad de intentos y aprender de sus errores "*a la mala*", los académicos lograron levantar un [repositorio](https://github.com/MDS7202/lab1) en `Github`. Usando el repositorio de los académicos, responda las siguientes preguntas (**incluya también los comandos en `Git` ocupados**):

# %% [markdown]
# 1. Clone el repositorio a su ambiente local. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>

# %% [markdown]
# git clone https://github.com/MDS7202/lab1

# %% [markdown]
# 2. Descomprima los archivos subidos con la tarea en U-cursos en la carpeta recién clonada de github. Una vez realizado esto, cree un archivo `.gitignore` con el cual omita la carpeta `videos` y los archivos con la extensión `.txt` exceptuando el archivo `171.txt` de la carpeta `texts`. (0.25 pts)

# %% [markdown]
# <code>Para esta pregunta usted deberá adjuntar el .gitignore creado en su repo.</code>

# %%
# Todos los videos
videos/

# Todos los archivos de texto menos el 171.txt
texts/*.txt
# !texts/171.txt

# %% [markdown]
# 3. Inspeccione brevemente el repositorio: ¿Cual es el objetivo del proyecto? Explique brevemente la estructura del proyecto, asi como también cada elemento que lo conforma. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>

# %% [markdown]
# El objetivo del proyecto es emular sonidos de animales (gatos, perros y zorros). Su estructura consta de tres archivos principales: animales.py, main.py, y readme.md. En el primer archivo se define una función relacionada al animal y su respectivo sonido. El segundo archivo se inicializa una función que recibe el nombre del animal y llama a animales.py para responder. El último archivo contiene una pequeña descripción del proyecto.

# %% [markdown]
# 4. Identifique los últimos cambios al repositorio, reconociendo las principales ramas de trabajo. ¿Son informativos los `commit` realizados? (0.25 pts)
# *Hint: Se recomienda usar los argumentos `all`, `graph` y `decorate`*

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>

# %% [markdown]
# R: Se tienen 4 commits, donde cada uno realiza lo siguiente:
# C1: Primer commit
# C2: Agrega alguna función
# C3: Se separa el proyecto en modulos (en este se realizan más ramas desde el origen : origin/new_features, origin/main, origin/HEAD)
# C4: fix ifs (arregla los ifs)
#
# Al realizar git log -all -graph -decorate se obtiene:
#
# * commit 25543a3baf77292baf849726784ca005473acab1 (origin/fix-ifs)
#
# | Author: Pablo Badilla <pbadilla.torrealba@gmail.com>
#
# | Date:   Thu Mar 23 22:50:49 2023 -0300
# |
# |     fix ifs
# |
# | * commit 362fe21ee44f53ee944cee4ba484600308f83d78 (HEAD -> main, origin/new_features, origin/main, origin/HEAD)
#
# |/  Author: mezosky <ignacio.meza@ug.uchile.cl>
#
# |   Date:   Thu Mar 23 21:47:34 2023 -0300
# |
# |       Se separa el proyecto en modulos
# |
# * commit c8b1a62d7299552b0654f930d695b33109214111
#
# | Author: seba <stinoco@fen.uchile.cl>
#
# | Date:   Wed Mar 22 17:28:19 2023 -0300
# |
# |     se agrega funcion
# |
# * commit b262d86411a6b017e99bf0731e33a6787739247c
#
#   Author: seba <stinoco@fen.uchile.cl>
#
#   Date:   Wed Mar 22 17:25:30 2023 -0300
#
#       primer commit
#
# Algunos commits no son muy informativos (la mayoria) ya que no especifican lo que hacen (por ejemplo: "agrega funcion" no detalla la función de la que esta hablando)

# %% [markdown]
# 5. Uno de los académicos se da cuenta que la rama principal de trabajo no se ejecuta correctamente para todos los argumentos. Señale y explique el error en el código e identifique a la persona que lo cometió usando `git blame` (0.25 pts)
#
# *Hint: Le puede ser útil esta [documentación](https://www.atlassian.com/es/git/tutorials/inspecting-a-repository/git-blame).*

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>

# %% [markdown]
# Al realizar git blame sobre animales.py, se obtiene lo siguiente:

# %%
362fe21e (mezosky 2023-03-23 21:47:34 -0300  1) def animales(input):
362fe21e (mezosky 2023-03-23 21:47:34 -0300  2)
362fe21e (mezosky 2023-03-23 21:47:34 -0300  3)     '''
362fe21e (mezosky 2023-03-23 21:47:34 -0300  4)     Como hace el animalito?
362fe21e (mezosky 2023-03-23 21:47:34 -0300  5)     '''
362fe21e (mezosky 2023-03-23 21:47:34 -0300  6)
362fe21e (mezosky 2023-03-23 21:47:34 -0300  7)     if input.lower() == 'gato':
362fe21e (mezosky 2023-03-23 21:47:34 -0300  8)         print('miau')
362fe21e (mezosky 2023-03-23 21:47:34 -0300  9)     if input.lower() == 'perro':
362fe21e (mezosky 2023-03-23 21:47:34 -0300 10)         print('guau')
362fe21e (mezosky 2023-03-23 21:47:34 -0300 11)     if input.lower() == 'fox':
362fe21e (mezosky 2023-03-23 21:47:34 -0300 12)         print('https://www.youtube.com/watch?v=jofNR_WkoCE')
362fe21e (mezosky 2023-03-23 21:47:34 -0300 13)     else:
362fe21e (mezosky 2023-03-23 21:47:34 -0300 14)         raise ValueError('animal no reconocido :(')

# %% [markdown]
# El error presente en el código es que se utilizan 3 if seguidos, lo cual causa el problema, en lugar de 'if' en el segundo y tercer if, se deberia utilizar 'elif'. Por lo tanto, la persona que cometio el error fue mezosky.

# %% [markdown]
# 6. Busque los siguientes `commit`:
#
# - `c8b1a62d7299552b0654f930d695b33109214111`
# - `362fe21ee44f53ee944cee4ba484600308f83d78`
# - `25543a3baf77292baf849726784ca005473acab1`
#
# ¿Qué diferencias existen entre cada uno? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>

# %% [markdown]
# El primero agrega las funciones de animales en main.py.
#
# El segundo separa el proyecto en modulos, es decir, agrega el archivo animales.py
#
# El tercero cambia los if por elif (arreglando el problema anteriormente mencionado pero solo en la rama fix-ifs)

# %% [markdown]
# 7. Realice una `merge` de la rama `fix-ifs` con la rama `main` y describa lo que ocurre. ¿Qué parte del código podría estar ocasionando esto? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>

# %% [markdown]
# Al insertar el codigo git merge origin/fix-ifs, arroja el siguiente resultado:
#
# Auto-merging main.py
#
# CONFLICT (content): Merge conflict in main.py
#
# Automatic merge failed; fix conflicts and then commit the result.
#
# La parte del codigo que puede estar ocasionando esto es animales.py ya que tienen diferencias (de if y elif) en las mismas lineas de codigo

# %% [markdown]
# 8. Cree una rama nueva y proponga una solución al problema anterior, adjuntando el código corregido y señalando las líneas modificadas. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>

# %% [markdown]
# Se crea la nueva rama con "git branch fix-total", para posicionar dentro de ella se utiliza "git checkout fix-total".
#
# Luego se corrige el código de animales.py:
#
# def animales(input):
#
#     '''
#     Como hace el animalito?
#     '''
#
#     if input.lower() == 'gato':
#         print('miau')
#     (-) if input.lower() == 'perro':
#     (+) elif input.lower() == 'perro':
#         print('guau')
#     (-) if input.lower() == 'fox':
#     (+) elif input.lower() == 'fox': #
#         print('https://www.youtube.com/watch?v=jofNR_WkoCE')
#     else:
#         raise ValueError('animal no reconocido :(')
#
# Por ultimo se realiza "git add animales.py", seguido por un "git commit -m "fix animales.py"" y finalmente un merge entre el main y la rama creada, es decir, "git merge fix-total main"

# %% [markdown]
# ## Fin

# %% [markdown]
# Eso ha sido todo por ahora!! Esperamos que este laboratorio les haya gustado y servido para trabajar con `Git`. Recuerden los dias de plazo que tienen disponibles y que ante cualquier duda no duden en contactar al equipo docente.
#
# Nos vemos!!
#
# <p align="center">
#   <img src="https://media.tenor.com/OYLdav9k9LkAAAAd/kitty-cat.gif" width="350">
# </p>
